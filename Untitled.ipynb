# %%
import numpy as np
import cv2

# %%
import numpy as np
import cv2

image = cv2.imread('test.png')
cv2.waitKey(500)

# Grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Find Canny edges
edged = cv2.Canny(gray, 30, 200)
cv2.waitKey(500)

# Finding Contours
# Use a copy of the image e.g. edged.copy()
# since findContours alters the image
contours, hierarchy = cv2.findContours(edged,
    cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

cv2.imshow('Canny Edges After Contouring', edged)
cv2.waitKey(500)

print("Number of Contours found = " + str(len(contours)))

# Draw all contours
# -1 signifies drawing all contours
cv2.drawContours(image, contours, -1, (0, 255, 0), 3)

cv2.imshow('Contours', image)
cv2.waitKey(5000)
cv2.destroyAllWindows()

print(contours)
# Out:
# Number of Contours found = 3
# [array([[[236,  87]],
#
#        [[236,  88]],
#
#        [[235,  89]],
#
#        ...,
#
#        [[239,  87]],
#
#        [[238,  87]],
#
#        [[237,  87]]], dtype=int32), array([[[134,  86]],
#
#        [[135,  86]],
#
#        [[136,  86]],
#
#        [[137,  86]],
#
#        [[138,  87]],
#
#        [[139,  88]],
#
#        [[139,  89]],
#
#        [[139,  90]],
#
#        [[139,  91]],
#
#        [[139,  92]],
#
#        [[139,  93]],
#
#        [[139,  94]],
#
#        [[139,  95]],
#
#        [[139,  96]],
#
#        [[139,  97]],
#
#        [[139,  98]],
#
#        [[139,  99]],
#
#        [[139, 100]],
#
#        [[139, 101]],
#
#        [[139, 102]],
#
#        [[140, 103]],
#
#        [[141, 104]],
#
#        [[141, 105]],
#
#        [[141, 106]],
#
#        [[141, 107]],
#
#        [[141, 108]],
#
#        [[141, 109]],
#
#        [[141, 110]],
#
#        [[141, 111]],
#
#        [[141, 112]],
#
#        [[141, 113]],
#
#        [[141, 114]],
#
#        [[142, 115]],
#
#        [[143, 115]],
#
#        [[144, 115]],
#
#        [[145, 115]],
#
#        [[146, 115]],
#
#        [[147, 115]],
#
#        [[148, 115]],
#
#        [[149, 115]],
#
#        [[150, 115]],
#
#        [[151, 115]],
#
#        [[152, 115]],
#
#        [[153, 115]],
#
#        [[154, 115]],
#
#        [[155, 115]],
#
#        [[156, 115]],
#
#        [[157, 115]],
#
#        [[158, 115]],
#
#        [[159, 115]],
#
#        [[160, 115]],
#
#        [[161, 115]],
#
#        [[162, 115]],
#
#        [[163, 115]],
#
#        [[164, 115]],
#
#        [[165, 115]],
#
#        [[166, 115]],
#
#        [[167, 115]],
#
#        [[168, 115]],
#
#        [[169, 115]],
#
#        [[170, 115]],
#
#        [[171, 115]],
#
#        [[172, 115]],
#
#        [[173, 115]],
#
#        [[174, 115]],
#
#        [[175, 115]],
#
#        [[176, 115]],
#
#        [[177, 115]],
#
#        [[178, 115]],
#
#        [[179, 115]],
#
#        [[180, 115]],
#
#        [[181, 115]],
#
#        [[182, 115]],
#
#        [[183, 115]],
#
#        [[184, 115]],
#
#        [[185, 115]],
#
#        [[186, 115]],
#
#        [[187, 115]],
#
#        [[188, 115]],
#
#        [[189, 115]],
#
#        [[190, 115]],
#
#        [[191, 115]],
#
#        [[192, 115]],
#
#        [[193, 116]],
#
#        [[194, 116]],
#
#        [[195, 117]],
#
#        [[196, 117]],
#
#        [[197, 117]],
#
#        [[198, 117]],
#
#        [[199, 117]],
#
#        [[200, 117]],
#
#        [[201, 117]],
#
#        [[202, 118]],
#
#        [[203, 119]],
#
#        [[203, 120]],
#
#        [[203, 121]],
#
#        [[203, 122]],
#
#        [[203, 123]],
#
#        [[203, 124]],
#
#        [[203, 125]],
#
#        [[203, 126]],
#
#        [[203, 127]],
#
#        [[204, 127]],
#
#        [[205, 127]],
#
#        [[205, 126]],
#
#        [[205, 125]],
#
#        [[205, 124]],
#
#        [[205, 123]],
#
#        [[205, 122]],
#
#        [[205, 121]],
#
#        [[205, 120]],
#
#        [[205, 119]],
#
#        [[205, 118]],
#
#        [[205, 117]],
#
#        [[206, 116]],
#
#        [[206, 115]],
#
#        [[206, 114]],
#
#        [[206, 113]],
#
#        [[206, 112]],
#
#        [[206, 111]],
#
#        [[206, 110]],
#
#        [[206, 109]],
#
#        [[206, 108]],
#
#        [[206, 107]],
#
#        [[206, 106]],
#
#        [[206, 105]],
#
#        [[206, 104]],
#
#        [[206, 103]],
#
#        [[206, 102]],
#
#        [[206, 101]],
#
#        [[206, 100]],
#
#        [[206,  99]],
#
#        [[206,  98]],
#
#        [[206,  97]],
#
#        [[206,  96]],
#
#        [[206,  95]],
#
#        [[206,  94]],
#
#        [[206,  93]],
#
#        [[206,  92]],
#
#        [[206,  91]],
#
#        [[206,  90]],
#
#        [[206,  89]],
#
#        [[207,  88]],
#
#        [[208,  87]],
#
#        [[209,  86]],
#
#        [[210,  86]],
#
#        [[211,  86]],
#
#        [[212,  86]],
#
#        [[213,  86]],
#
#        [[214,  86]],
#
#        [[215,  86]],
#
#        [[216,  86]],
#
#        [[217,  86]],
#
#        [[218,  86]],
#
#        [[219,  86]],
#
#        [[220,  87]],
#
#        [[221,  88]],
#
#        [[221,  89]],
#
#        [[221,  90]],
#
#        [[221,  91]],
#
#        [[221,  92]],
#
#        [[221,  93]],
#
#        [[221,  94]],
#
#        [[221,  95]],
#
#        [[221,  96]],
#
#        [[221,  97]],
#
#        [[221,  98]],
#
#        [[221,  99]],
#
#        [[221, 100]],
#
#        [[221, 101]],
#
#        [[221, 102]],
#
#        [[221, 103]],
#
#        [[221, 104]],
#
#        [[221, 105]],
#
#        [[222, 106]],
#
#        [[223, 106]],
#
#        [[224, 106]],
#
#        [[225, 106]],
#
#        [[226, 106]],
#
#        [[227, 106]],
#
#        [[228, 106]],
#
#        [[229, 106]],
#
#        [[230, 106]],
#
#        [[231, 106]],
#
#        [[232, 107]],
#
#        [[233, 108]],
#
#        [[233, 107]],
#
#        [[232, 107]],
#
#        [[231, 106]],
#
#        [[230, 106]],
#
#        [[229, 106]],
#
#        [[228, 106]],
#
#        [[227, 106]],
#
#        [[226, 106]],
#
#        [[225, 106]],
#
#        [[224, 106]],
#
#        [[223, 106]],
#
#        [[222, 106]],
#
#        [[221, 105]],
#
#        [[221, 104]],
#
#        [[221, 103]],
#
#        [[221, 102]],
#
#        [[221, 101]],
#
#        [[221, 100]],
#
#        [[221,  99]],
#
#        [[221,  98]],
#
#        [[221,  97]],
#
#        [[221,  96]],
#
#        [[221,  95]],
#
#        [[221,  94]],
#
#        [[221,  93]],
#
#        [[221,  92]],
#
#        [[221,  91]],
#
#        [[221,  90]],
#
#        [[221,  89]],
#
#        [[221,  88]],
#
#        [[221,  87]],
#
#        [[220,  87]],
#
#        [[219,  86]],
#
#        [[218,  86]],
#
#        [[217,  86]],
#
#        [[216,  86]],
#
#        [[215,  86]],
#
#        [[214,  86]],
#
#        [[213,  86]],
#
#        [[212,  86]],
#
#        [[211,  86]],
#
#        [[210,  86]],
#
#        [[209,  86]],
#
#        [[208,  87]],
#
#        [[207,  87]],
#
#        [[207,  88]],
#
#        [[206,  89]],
#
#        [[206,  90]],
#
#        [[206,  91]],
#
#        [[206,  92]],
#
#        [[206,  93]],
#
#        [[206,  94]],
#
#        [[206,  95]],
#
#        [[206,  96]],
#
#        [[206,  97]],
#
#        [[206,  98]],
#
#        [[206,  99]],
#
#        [[206, 100]],
#
#        [[206, 101]],
#
#        [[206, 102]],
#
#        [[206, 103]],
#
#        [[206, 104]],
#
#        [[206, 105]],
#
#        [[206, 106]],
#
#        [[206, 107]],
#
#        [[206, 108]],
#
#        [[206, 109]],
#
#        [[206, 110]],
#
#        [[206, 111]],
#
#        [[206, 112]],
#
#        [[206, 113]],
#
#        [[206, 114]],
#
#        [[206, 115]],
#
#        [[206, 116]],
#
#        [[205, 117]],
#
#        [[204, 118]],
#
#        [[203, 118]],
#
#        [[202, 118]],
#
#        [[201, 117]],
#
#        [[200, 117]],
#
#        [[199, 117]],
#
#        [[198, 117]],
#
#        [[197, 117]],
#
#        [[196, 117]],
#
#        [[195, 117]],
#
#        [[194, 116]],
#
#        [[193, 116]],
#
#        [[192, 115]],
#
#        [[191, 115]],
#
#        [[190, 115]],
#
#        [[189, 115]],
#
#        [[188, 115]],
#
#        [[187, 115]],
#
#        [[186, 115]],
#
#        [[185, 115]],
#
#        [[184, 115]],
#
#        [[183, 115]],
#
#        [[182, 115]],
#
#        [[181, 115]],
#
#        [[180, 115]],
#
#        [[179, 115]],
#
#        [[178, 115]],
#
#        [[177, 115]],
#
#        [[176, 115]],
#
#        [[175, 115]],
#
#        [[174, 115]],
#
#        [[173, 115]],
#
#        [[172, 115]],
#
#        [[171, 115]],
#
#        [[170, 115]],
#
#        [[169, 115]],
#
#        [[168, 115]],
#
#        [[167, 115]],
#
#        [[166, 115]],
#
#        [[165, 115]],
#
#        [[164, 115]],
#
#        [[163, 115]],
#
#        [[162, 115]],
#
#        [[161, 115]],
#
#        [[160, 115]],
#
#        [[159, 115]],
#
#        [[158, 115]],
#
#        [[157, 115]],
#
#        [[156, 115]],
#
#        [[155, 115]],
#
#        [[154, 115]],
#
#        [[153, 115]],
#
#        [[152, 115]],
#
#        [[151, 115]],
#
#        [[150, 115]],
#
#        [[149, 115]],
#
#        [[148, 115]],
#
#        [[147, 115]],
#
#        [[146, 115]],
#
#        [[145, 115]],
#
#        [[144, 115]],
#
#        [[143, 115]],
#
#        [[142, 115]],
#
#        [[141, 114]],
#
#        [[141, 113]],
#
#        [[141, 112]],
#
#        [[141, 111]],
#
#        [[141, 110]],
#
#        [[141, 109]],
#
#        [[141, 108]],
#
#        [[141, 107]],
#
#        [[141, 106]],
#
#        [[141, 105]],
#
#        [[141, 104]],
#
#        [[141, 103]],
#
#        [[142, 102]],
#
#        [[142, 101]],
#
#        [[142, 100]],
#
#        [[142,  99]],
#
#        [[142,  98]],
#
#        [[142,  97]],
#
#        [[142,  96]],
#
#        [[142,  95]],
#
#        [[142,  94]],
#
#        [[142,  93]],
#
#        [[142,  92]],
#
#        [[142,  91]],
#
#        [[142,  90]],
#
#        [[142,  89]],
#
#        [[142,  88]],
#
#        [[142,  87]],
#
#        [[141,  86]],
#
#        [[140,  87]],
#
#        [[139,  87]],
#
#        [[138,  87]],
#
#        [[137,  86]],
#
#        [[136,  86]],
#
#        [[135,  86]]], dtype=int32), array([[[ 82,  81]],
#
#        [[ 81,  82]],
#
#        [[ 80,  82]],
#
#        [[ 80,  83]],
#
#        [[ 79,  84]],
#
#        [[ 79,  85]],
#
#        [[ 79,  86]],
#
#        [[ 79,  87]],
#
#        [[ 79,  88]],
#
#        [[ 79,  89]],
#
#        [[ 79,  90]],
#
#        [[ 79,  91]],
#
#        [[ 79,  92]],
#
#        [[ 79,  93]],
#
#        [[ 79,  94]],
#
#        [[ 79,  95]],
#
#        [[ 79,  96]],
#
#        [[ 79,  97]],
#
#        [[ 79,  98]],
#
#        [[ 79,  99]],
#
#        [[ 79, 100]],
#
#        [[ 79, 101]],
#
#        [[ 79, 102]],
#
#        [[ 79, 103]],
#
#        [[ 79, 104]],
#
#        [[ 79, 105]],
#
#        [[ 79, 106]],
#
#        [[ 79, 107]],
#
#        [[ 79, 108]],
#
#        [[ 79, 109]],
#
#        [[ 79, 110]],
#
#        [[ 79, 111]],
#
#        [[ 79, 112]],
#
#        [[ 79, 113]],
#
#        [[ 79, 114]],
#
#        [[ 79, 115]],
#
#        [[ 79, 116]],
#
#        [[ 79, 117]],
#
#        [[ 78, 118]],
#
#        [[ 77, 118]],
#
#        [[ 76, 118]],
#
#        [[ 75, 119]],
#
#        [[ 74, 120]],
#
#        [[ 73, 120]],
#
#        [[ 73, 121]],
#
#        [[ 72, 122]],
#
#        [[ 72, 123]],
#
#        [[ 72, 124]],
#
#        [[ 72, 125]],
#
#        [[ 72, 126]],
#
#        [[ 72, 127]],
#
#        [[ 72, 128]],
#
#        [[ 72, 129]],
#
#        [[ 72, 130]],
#
#        [[ 72, 131]],
#
#        [[ 72, 132]],
#
#        [[ 71, 133]],
#
#        [[ 71, 134]],
#
#        [[ 71, 135]],
#
#        [[ 71, 136]],
#
#        [[ 70, 137]],
#
#        [[ 69, 137]],
#
#        [[ 69, 138]],
#
#        [[ 69, 139]],
#
#        [[ 69, 140]],
#
#        [[ 69, 141]],
#
#        [[ 70, 141]],
#
#        [[ 71, 141]],
#
#        [[ 72, 142]],
#
#        [[ 72, 143]],
#
#        [[ 72, 142]],
#
#        [[ 71, 141]],
#
#        [[ 70, 141]],
#
#        [[ 69, 140]],
#
#        [[ 69, 139]],
#
#        [[ 69, 138]],
#
#        [[ 70, 137]],
#
#        [[ 71, 136]],
#
#        [[ 71, 135]],
#
#        [[ 71, 134]],
#
#        [[ 71, 133]],
#
#        [[ 72, 132]],
#
#        [[ 72, 131]],
#
#        [[ 72, 130]],
#
#        [[ 72, 129]],
#
#        [[ 72, 128]],
#
#        [[ 72, 127]],
#
#        [[ 72, 126]],
#
#        [[ 72, 125]],
#
#        [[ 72, 124]],
#
#        [[ 72, 123]],
#
#        [[ 72, 122]],
#
#        [[ 73, 121]],
#
#        [[ 74, 120]],
#
#        [[ 75, 119]],
#
#        [[ 76, 118]],
#
#        [[ 77, 118]],
#
#        [[ 78, 118]],
#
#        [[ 79, 119]],
#
#        [[ 79, 120]],
#
#        [[ 78, 121]],
#
#        [[ 77, 120]],
#
#        [[ 77, 121]],
#
#        [[ 78, 121]],
#
#        [[ 79, 121]],
#
#        [[ 79, 120]],
#
#        [[ 79, 119]],
#
#        [[ 79, 118]],
#
#        [[ 79, 117]],
#
#        [[ 79, 116]],
#
#        [[ 79, 115]],
#
#        [[ 79, 114]],
#
#        [[ 79, 113]],
#
#        [[ 79, 112]],
#
#        [[ 79, 111]],
#
#        [[ 79, 110]],
#
#        [[ 79, 109]],
#
#        [[ 79, 108]],
#
#        [[ 79, 107]],
#
#        [[ 79, 106]],
#
#        [[ 79, 105]],
#
#        [[ 79, 104]],
#
#        [[ 79, 103]],
#
#        [[ 79, 102]],
#
#        [[ 79, 101]],
#
#        [[ 79, 100]],
#
#        [[ 79,  99]],
#
#        [[ 79,  98]],
#
#        [[ 79,  97]],
#
#        [[ 79,  96]],
#
#        [[ 79,  95]],
#
#        [[ 79,  94]],
#
#        [[ 79,  93]],
#
#        [[ 79,  92]],
#
#        [[ 79,  91]],
#
#        [[ 79,  90]],
#
#        [[ 79,  89]],
#
#        [[ 79,  88]],
#
#        [[ 79,  87]],
#
#        [[ 79,  86]],
#
#        [[ 79,  85]],
#
#        [[ 79,  84]],
#
#        [[ 80,  83]],
#
#        [[ 81,  82]],
#
#        [[ 82,  81]],
#
#        [[ 83,  81]],
#
#        [[ 84,  81]],
#
#        [[ 85,  81]],
#
#        [[ 86,  81]],
#
#        [[ 87,  81]],
#
#        [[ 88,  81]],
#
#        [[ 89,  81]],
#
#        [[ 90,  81]],
#
#        [[ 91,  81]],
#
#        [[ 92,  81]],
#
#        [[ 93,  81]],
#
#        [[ 94,  81]],
#
#        [[ 95,  81]],
#
#        [[ 96,  81]],
#
#        [[ 97,  81]],
#
#        [[ 98,  81]],
#
#        [[ 99,  81]],
#
#        [[100,  81]],
#
#        [[101,  81]],
#
#        [[102,  81]],
#
#        [[103,  81]],
#
#        [[104,  81]],
#
#        [[105,  81]],
#
#        [[106,  81]],
#
#        [[107,  81]],
#
#        [[108,  81]],
#
#        [[109,  81]],
#
#        [[110,  82]],
#
#        [[111,  83]],
#
#        [[111,  84]],
#
#        [[111,  85]],
#
#        [[111,  86]],
#
#        [[111,  87]],
#
#        [[111,  88]],
#
#        [[111,  89]],
#
#        [[111,  90]],
#
#        [[111,  91]],
#
#        [[112,  92]],
#
#        [[113,  93]],
#
#        [[114,  94]],
#
#        [[114,  95]],
#
#        [[114,  96]],
#
#        [[113,  97]],
#
#        [[112,  98]],
#
#        [[111,  99]],
#
#        [[111, 100]],
#
#        [[111, 101]],
#
#        [[111, 102]],
#
#        [[111, 103]],
#
#        [[111, 104]],
#
#        [[111, 105]],
#
#        [[111, 106]],
#
#        [[111, 107]],
#
#        [[111, 108]],
#
#        [[111, 109]],
#
#        [[111, 110]],
#
#        [[111, 111]],
#
#        [[111, 112]],
#
#        [[112, 113]],
#
#        [[113, 113]],
#
#        [[114, 113]],
#
#        [[115, 113]],
#
#        [[116, 113]],
#
#        [[117, 113]],
#
#        [[118, 113]],
#
#        [[119, 113]],
#
#        [[120, 113]],
#
#        [[121, 113]],
#
#        [[122, 113]],
#
#        [[123, 113]],
#
#        [[124, 113]],
#
#        [[125, 113]],
#
#        [[126, 113]],
#
#        [[127, 113]],
#
#        [[128, 113]],
#
#        [[129, 113]],
#
#        [[130, 113]],
#
#        [[131, 113]],
#
#        [[131, 112]],
#
#        [[131, 111]],
#
#        [[131, 110]],
#
#        [[131, 109]],
#
#        [[131, 108]],
#
#        [[131, 107]],
#
#        [[131, 106]],
#
#        [[131, 105]],
#
#        [[131, 104]],
#
#        [[131, 103]],
#
#        [[131, 102]],
#
#        [[131, 101]],
#
#        [[131, 100]],
#
#        [[131,  99]],
#
#        [[131,  98]],
#
#        [[131,  97]],
#
#        [[131,  96]],
#
#        [[131,  95]],
#
#        [[131,  94]],
#
#        [[131,  93]],
#
#        [[131,  92]],
#
#        [[131,  91]],
#
#        [[131,  90]],
#
#        [[131,  89]],
#
#        [[131,  88]],
#
#        [[131,  87]],
#
#        [[131,  86]],
#
#        [[131,  85]],
#
#        [[131,  84]],
#
#        [[132,  83]],
#
#        [[133,  82]],
#
#        [[132,  82]],
#
#        [[132,  83]],
#
#        [[131,  84]],
#
#        [[131,  85]],
#
#        [[131,  86]],
#
#        [[131,  87]],
#
#        [[131,  88]],
#
#        [[131,  89]],
#
#        [[131,  90]],
#
#        [[131,  91]],
#
#        [[131,  92]],
#
#        [[131,  93]],
#
#        [[131,  94]],
#
#        [[131,  95]],
#
#        [[131,  96]],
#
#        [[131,  97]],
#
#        [[131,  98]],
#
#        [[131,  99]],
#
#        [[131, 100]],
#
#        [[131, 101]],
#
#        [[131, 102]],
#
#        [[131, 103]],
#
#        [[131, 104]],
#
#        [[131, 105]],
#
#        [[131, 106]],
#
#        [[131, 107]],
#
#        [[131, 108]],
#
#        [[131, 109]],
#
#        [[131, 110]],
#
#        [[131, 111]],
#
#        [[131, 112]],
#
#        [[130, 113]],
#
#        [[129, 113]],
#
#        [[128, 113]],
#
#        [[127, 113]],
#
#        [[126, 113]],
#
#        [[125, 113]],
#
#        [[124, 113]],
#
#        [[123, 113]],
#
#        [[122, 113]],
#
#        [[121, 113]],
#
#        [[120, 113]],
#
#        [[119, 113]],
#
#        [[118, 113]],
#
#        [[117, 113]],
#
#        [[116, 113]],
#
#        [[115, 113]],
#
#        [[114, 113]],
#
#        [[113, 113]],
#
#        [[112, 113]],
#
#        [[111, 112]],
#
#        [[111, 111]],
#
#        [[111, 110]],
#
#        [[111, 109]],
#
#        [[111, 108]],
#
#        [[111, 107]],
#
#        [[111, 106]],
#
#        [[111, 105]],
#
#        [[111, 104]],
#
#        [[111, 103]],
#
#        [[111, 102]],
#
#        [[111, 101]],
#
#        [[111, 100]],
#
#        [[111,  99]],
#
#        [[112,  98]],
#
#        [[113,  97]],
#
#        [[114,  97]],
#
#        [[114,  96]],
#
#        [[114,  95]],
#
#        [[114,  94]],
#
#        [[114,  93]],
#
#        [[113,  93]],
#
#        [[112,  92]],
#
#        [[111,  91]],
#
#        [[111,  90]],
#
#        [[111,  89]],
#
#        [[111,  88]],
#
#        [[111,  87]],
#
#        [[111,  86]],
#
#        [[111,  85]],
#
#        [[111,  84]],
#
#        [[111,  83]],
#
#        [[111,  82]],
#
#        [[110,  82]],
#
#        [[109,  81]],
#
#        [[108,  81]],
#
#        [[107,  81]],
#
#        [[106,  81]],
#
#        [[105,  81]],
#
#        [[104,  81]],
#
#        [[103,  81]],
#
#        [[102,  81]],
#
#        [[101,  81]],
#
#        [[100,  81]],
#
#        [[ 99,  81]],
#
#        [[ 98,  81]],
#
#        [[ 97,  81]],
#
#        [[ 96,  81]],
#
#        [[ 95,  81]],
#
#        [[ 94,  81]],
#
#        [[ 93,  81]],
#
#        [[ 92,  81]],
#
#        [[ 91,  81]],
#
#        [[ 90,  81]],
#
#        [[ 89,  81]],
#
#        [[ 88,  81]],
#
#        [[ 87,  81]],
#
#        [[ 86,  81]],
#
#        [[ 85,  81]],
#
#        [[ 84,  81]],
#
#        [[ 83,  81]]], dtype=int32)]

# %%
image = cv2.imread('test.jpg') 
cv2.waitKey(5000) 
  
# Grayscale 
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) 
  
# Find Canny edges 
edged = cv2.Canny(gray, 30, 200) 
cv2.waitKey(5000) 
  
# Finding Contours 
# Use a copy of the image e.g. edged.copy() 
# since findContours alters the image 
contours, hierarchy = cv2.findContours(edged,  
    cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE) 
  
cv2.imshow('Canny Edges After Contouring', edged) 
cv2.waitKey(5000) 
  
print("Number of Contours found = " + str(len(contours))) 
  
# Draw all contours 
# -1 signifies drawing all contours 
cv2.drawContours(image, contours, -1, (0, 255, 0), 3) 
  
cv2.imshow('Contours', image) 
cv2.waitKey(5000) 
cv2.destroyAllWindows()
